# %% [markdown]
# <a href="https://colab.research.google.com/github/mukteshsingh95/Play-Store-App/blob/main/Play_Store_App.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing libraries
# numpy-for linear transformation
# pandas-for data manipulation and analysis
# matplotlib,seaborn,plotly-for visualization
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
#Mounting the drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#loading csv files
playstore_data_path = '/content/drive/MyDrive/DATA/Play Store Data (1).csv'
user_review_data_path = '/content/drive/MyDrive/DATA/User Reviews (1).csv'
playstore_df = pd.read_csv(playstore_data_path)
review_df = pd.read_csv(user_review_data_path)

# %% [markdown]
# # **Exploring Playstore and User Review Dataframe.**
#
# **1**.**Playstore** **Dataframe**

# %%
#shape of the play store dataset
playstore_df.shape
# Out:
# (10841, 13)

# %%
#displaying first 5 rows of the dataset
playstore_df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
#displaying last 5 rows of the dataset
playstore_df.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
# information about the features in the dataset
playstore_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
#shape of the Review dataset
review_df.shape
# Out:
# (64295, 5)

# %%
#displaying first 5 rows of the dataset
review_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#displaying last 5 rows of the dataset
review_df.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
# information about the features in the dataset
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# # **Lets explore all the features in the Dataset**
#
# **App** - describes the name of each apps.
#
# **Category** - Category at which the app belongs.
#
#
# **Rating** -Average rating of the app received from its users.
#
# **Reviews** - The total number of reviews got by the apps from its users.
#
# **Size**- Memory size occupied by the app in the mobile device.
#
# **Installs**- The total number of downloads for the application.
#
# **Type** - whether the app is free or paid
#
# **Price**-If the app is paid, what is the cost required to install the app.
#
# **Content Rating** - It specifies weather the app is suitable for all age group or not.
#
# **Genres**- the other categories to which the app can belong.
#
# **Last Updated**- Last updated date of the app.
#
# **Current Ver**-The current version of the app.
#
# **Android Ver**-The Android Version which can support the application.

# %% [markdown]
# # **2.Review Dataframe**

# %%
#shape of the Review dataset
review_df.shape
# Out:
# (64295, 5)

# %%
#displaying first 5 rows of the dataset
review_df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#displaying last 5 rows of the dataset
review_df.tail()
# Out:
#                                App Translated_Review Sentiment  \
# 64290  Houzz Interior Design Ideas               NaN       NaN
# 64291  Houzz Interior Design Ideas               NaN       NaN
# 64292  Houzz Interior Design Ideas               NaN       NaN
# 64293  Houzz Interior Design Ideas               NaN       NaN
# 64294  Houzz Interior Design Ideas               NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 64290                 NaN                     NaN
# 64291                 NaN                     NaN
# 64292                 NaN                     NaN
# 64293                 NaN                     NaN
# 64294                 NaN                     NaN

# %%
# information about the features in the dataset
review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# # **Lets explore all the features in the Dataset**
#
# 1. **App** - describes the name of each apps.
#
# 2. **Translated_Review**-English translation of the user reviews.
#
# 3. **Sentiment** - It gives the emotion of the reviewer related with his review.It can be ‘Positive’, ‘Negative’, or ‘Neutral’.
# Sentiment_Polarity - The polarity of the review.It ranges from [-1 to 1]. -1 means "negative sentiment" and 1 means "positive sentiment"
#
# 4. **Sentiment_Subjectivity** - How the opinion of a particular reviewer is aligned with the opinion of the general public.It ranges from [0 to 1]. Heigher the subjectivity means the review is closer to the opinion of general public.

# %% [markdown]
# # **Data Cleaning**
#
# # **Play Store Dataset**

# %%
#Making copy of playstore dataframe
df = playstore_df.copy()

# %% [markdown]
# # **1- Converting "Review" column type from "object" to "int".**

# %%
df['Reviews']=df['Reviews'].apply(lambda x : eval(x))
# Out:
# Traceback (most recent call last):
#
#   File "/usr/local/lib/python3.9/dist-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-92-377d2d6462cf>", line 1, in <module>
#     df['Reviews']=df['Reviews'].apply(lambda x : eval(x))
#
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/series.py", line 4357, in apply
#     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/apply.py", line 1043, in apply
#     return self.apply_standard()
#
#   File "/usr/local/lib/python3.9/dist-packages/pandas/core/apply.py", line 1098, in apply_standard
#     mapped = lib.map_infer(
#
#   File "pandas/_libs/lib.pyx", line 2859, in pandas._libs.lib.map_infer
#
#   File "<ipython-input-92-377d2d6462cf>", line 1, in <lambda>
#     df['Reviews']=df['Reviews'].apply(lambda x : eval(x))
#
#   File "<string>", line 1
#     3.0M
#        ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
#  **While converting Reviews into "int" type we found some Error. Which show that one of the value in review column is 3.0M.So we have to remove that row from the data set.**

# %%
# Finding the row index of that value.
df[df['Reviews']=='3.0M']
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %% [markdown]
#  **We have found that index no 10472 contain the value 3.0M.**

# %%
# Dropping that index value using drop method and reseting index again.
df = df.drop(10472).reset_index(drop=True)

# %%
# Evaluating the values.
df['Reviews']=df['Reviews'].apply(lambda x : eval(x))

# %% [markdown]
# # **2- Converting "Size" column type from "object" to "float".**

# %%
#printing last 5 rows of dataset
df.tail()
# Out:
#                                                  App             Category  \
# 10835                               Sya9a Maroc - FR               FAMILY
# 10836               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10837                         Parkinson Exercices FR              MEDICAL
# 10838                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10839  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating  Reviews                Size     Installs  Type Price  \
# 10835     4.5       38                 53M       5,000+  Free     0
# 10836     5.0        4                3.6M         100+  Free     0
# 10837     NaN        3                9.5M       1,000+  Free     0
# 10838     4.5      114  Varies with device       1,000+  Free     0
# 10839     4.5   398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10835       Everyone          Education     July 25, 2017                1.48
# 10836       Everyone          Education      July 6, 2018                 1.0
# 10837       Everyone            Medical  January 20, 2017                 1.0
# 10838     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10839       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10835          4.1 and up
# 10836          4.1 and up
# 10837          2.2 and up
# 10838  Varies with device
# 10839  Varies with device

# %% [markdown]
# # It is observed that "Size column contain values in MB (M), kb(k) and "Varies with device".

# %%
# Checking the shape of size column which is equal to Varies with device
df[df['Size']=='Varies with device'].shape
# Out:
# (1695, 13)

# %% [markdown]
# In the size coloumn the sizes are in different units. Some of them are in 'M' means MB some of them are in 'K' means KB.For those which are in MB we just convert it to float after removing the 'M' charecter from it. For those which are in KB first we convert it to float after removing 'K from it than we convert it to MB by dividing it by **1024**
#
# Again we can see there are **1695 rows** that has "**Varies with device"** value in **"Size"** column. Replacing this value with mean value will affect the visualization. Replacing Varies with device value with np.NaN which is of float type.

# %%
def converting_size_into_float(string):
  '''
  This function helps in removing 'M'(MB) and 'k'(kb) which are present at 
  the end of the string and replace 'Varies with device' with np.NaN.
   This function also evaluate the values present. 
  '''
  
  if string[-1] == 'M':
    return eval(string.strip('M'))

  elif string[-1] == 'k':
    a =string.strip('k')
    b = str(round(eval(a)/1024,1))
    return eval(b)

  elif string == 'Varies with device':
    string = np.NaN  
    return string
  else:
    return eval(string)

# %%
# Applying defined function.
df['Size_in_MB']= df['Size'].apply(lambda x : converting_size_into_float(x))

# %% [markdown]
# # 3- Converting "Install" column type from "object to "int".
#
# In **Install** column values are of **object** type and contain '+' and ',' in them. So we are going remove '+' and ',' from the values and then convert them into **int** type using **eval** method.

# %%
# Creating function to remove + and ,.
def remove_plus_and_comma(string):
  '''
  This function removes '+' and ',' from the string.
  '''
  string = string.replace(',','')
  string = string.strip('+')
  return string

# %%
# Applying defined function on the column and evaluating those values.
df['Installs'] = df['Installs'].apply(lambda x: eval(remove_plus_and_comma(x)))

# %% [markdown]
# # 4- Converting **"Price"** column type from **"object"** to **"float"**.
# **Price** column value has $ symbol in them and they are of object type. we'll remove the symbol and change the type.

# %%
# Creating function to remove $ symbol.
def remove_sign(string):
  '''
  This function removes $ symbol from the string and convert given string data type from 'str' to 'float'.
  '''
  return round(float(string.strip('$')),2)

# %%
# Applying the function.
df['price_in_dollar'] = df['Price'].apply(lambda x : remove_sign(x))

# %% [markdown]
# ### 5- Converting **Last Update** type from **"object"** to **"datetime"**.

# %%
# Converting str into datetime formate using 'to_datetime' function.
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

# %% [markdown]
# # **Handling the NaN values**

# %%
# Total number of null values in the dataframe 
df.isnull().sum()
# Out:
# App                   0
# Category              0
# Rating             1474
# Reviews               0
# Size                  0
# Installs              0
# Type                  1
# Price                 0
# Content Rating        0
# Genres                0
# Last Updated          0
# Current Ver           8
# Android Ver           2
# Size_in_MB         1695
# price_in_dollar       0
# dtype: int64

# %% [markdown]
# # 6- Handling Rating column

# %%
#checking the null value in Rating colunn
len(df[df['Rating'].isnull()]['Rating'])
# Out:
# 1474

# %% [markdown]
# # Rating column contain 1474 NaN values. We cannot drop this much amount of row from dataset because it will lose a huge percentage of information.We gonna replace all the NaN values with the average of non-null values.

# %%
# Finding average of non-null values from Rating column.
non_null_mean= round(df[~df['Rating'].isnull()]['Rating'].mean(),1)

# %%
# Replacing null values with average rating.
df['Rating'].fillna(value= non_null_mean, inplace=True)

# %% [markdown]
# # 7- Removing Null value from "Type" column.
#
# **Type** column contain only one NaN value.

# %%
# checking the null value in Type colunn
df[df['Type'].isnull()]['Type']
# Out:
# 9148    NaN
# Name: Type, dtype: object

# %% [markdown]
# It is observed that Type column contain Null value at index 9148.

# %%
# Removing row having index 9148 and reseting the index.
df = df.drop(9148).reset_index(drop=True)

# %% [markdown]
# # **8- Removing Null values from "Current Ver".**

# %%
# checking shape of null value in Current Ver colunn
df[df['Current Ver'].isnull()]['Current Ver'].shape
# Out:
# (8,)

# %% [markdown]
# ## **Number of Null value present in the 'Current Ver' column is 8.**

# %%
# Removing the rows containing Null values from Dataframe.
df = df[~df['Current Ver'].isnull()]

# %% [markdown]
# # **9- Removing Null values from "Android Ver" column.**

# %%
# checking the null value in Android colunn
len(df[df['Android Ver'].isnull()]['Android Ver'])
# Out:
# 2

# %% [markdown]
# # Number of Null values present in the "Android Ver" column is 2.

# %%
# Removing Rows containing Null value from dataframe.
df= df[~df['Android Ver'].isnull()]

# %% [markdown]
# ## **Android Ver type is of object and there are different values. we'll get the create another column in the Dataframe which will store the minimum android version for the App.**

# %%
def get_ver(string):
  '''
  This function is used to obtain minimum android version required.
  '''

  if string =='Varies with device':
    return eval('1.0')
  else:
    string = string[0:3]
    return eval(string)

# %%
# Applying the function.
df['min_ver']=df['Android Ver'].apply(lambda x : get_ver(x))

# %% [markdown]
# # **Checking and Removing Duplicate values from the data set.**
#
# As we can see in the Dataframe only one column that contain **UNIQUE** value which cannot be repeate and that column is **App** column.

# %%
# Creating temperory dataframe to find the number of duplicate apps.
a = df['App'].value_counts().reset_index()

# %%
# Finding the number of duplicate rows.
len(a[a['App']>=2])
# Out:
# 798

# %% [markdown]
# ## **As we can see above Dataframe contains 798 duplicate rows.**

# %%
# Removing DUPLICATES from the Dataframe.
df=df.drop_duplicates(subset = 'App')

# %%
df=df.reset_index()

# %%
#Dropping the index
df.drop(['index'],axis = 1,inplace=True)

# %%
# Checking the shape of the dataframe
df.shape
# Out:
# (9648, 16)

# %% [markdown]
# ## - After removing **"Duplicates"** and **"NaN values"** from the Dataframe we now have a modified Dataframe with 9648 rows and 16 columns.
#
# # **2.User Review dataset**

# %%
#Creating a copy of review dataset
r_df = review_df.copy()

# %%
# Information of r_df
r_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64295 entries, 0 to 64294
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     64295 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37432 non-null  object
#  3   Sentiment_Polarity      37432 non-null  float64
#  4   Sentiment_Subjectivity  37432 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 2.5+ MB

# %% [markdown]
# ## Handling Null values in User data review Dataframe.

# %%
# Total number of null values
r_df.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Checking the shape of null values in Translated Review
r_df[r_df['Translated_Review'].isnull()].shape
# Out:
# (26868, 5)

# %% [markdown]
# # #There are 26868 Null Values in **Translated Review** column.
# ## Removing NaN values from **Translated_Review** column, cause the rows containing NaN values are of no use and we cannot impute null values for these column.
# ## If there is no review then there will be no sentiment.
# ## Therefore, We will remove all the rows that contains NaN values in Translated_Review columm.

# %%
# Removing the null value in Translated Review colunn
r_df= r_df[~r_df['Translated_Review'].isnull()]

# %%
r_df= r_df.reset_index()

# %%
#Dropping the index
r_df.drop(['index'],axis=1,inplace=True)

# %%
# Information about the dataset
r_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37427 entries, 0 to 37426
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37427 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37427 non-null  object
#  3   Sentiment_Polarity      37427 non-null  float64
#  4   Sentiment_Subjectivity  37427 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB

# %% [markdown]
# # **Data Visualization**
#
# # Q1-Correlation Heatmap

# %%
# Checking for correlation between different variables
df.corr()
# Out:
#                    Rating   Reviews  Installs  Size_in_MB  price_in_dollar  \
# Rating           1.000000  0.054032  0.038869    0.055865        -0.019378
# Reviews          0.054032  1.000000  0.625158    0.179275        -0.007604
# Installs         0.038869  0.625158  1.000000    0.134216        -0.009413
# Size_in_MB       0.055865  0.179275  0.134216    1.000000        -0.022500
# price_in_dollar -0.019378 -0.007604 -0.009413   -0.022500         1.000000
# min_ver         -0.005648 -0.092561 -0.134702    0.139515         0.018573
#
#                   min_ver
# Rating          -0.005648
# Reviews         -0.092561
# Installs        -0.134702
# Size_in_MB       0.139515
# price_in_dollar  0.018573
# min_ver          1.000000

# %%
# Heat map for play_store
plt.rcParams['figure.figsize'] = (15, 8)
sns.heatmap(df.corr(), annot= True)
plt.title('Corelation Heatmap for Playstore Data', size=20)
# Out:
# Text(0.5, 1.0, 'Corelation Heatmap for Playstore Data')

# %% [markdown]
# # **Observation:**
# * There is a strong positive correlation between the Reviews and Installs column. This is pretty much obvious. Higher the number of installs, higher is the user base, and higher are the total number of reviews dropped by the users.
#
# * The Price is slightly negatively correlated with the Rating, Reviews, and Installs.` This means that as the prices of the app increases, the average rating, total number of reviews and Installs fall slightly.
#
# * The Rating is slightly positively correlated with the Installs and Reviews` column. This indicates that as the average user rating increases, the app installs and number of reviews also increase.

# %% [markdown]
# ## **Let us check if there is any co-relation in both the dataframes.**

# %%
# Merging both the datasets on App column
merged_df = pd.merge(df, r_df, on='App', how = "inner")

# %%
def merged_dfinfo():
  ''' Function to get information like data type, null values etc
  of merged dataframe columns'''
  temp = pd.DataFrame(index=merged_df.columns)
  temp['data_type'] = merged_df.dtypes
  temp["count of non null values"] = merged_df.count()
  temp['NaN values'] = merged_df.isnull().sum()
  temp['% NaN values'] =merged_df.isnull().mean()
  temp['unique_count'] = merged_df.nunique() 
  return temp
merged_dfinfo()
# Out:
#                              data_type  count of non null values  NaN values  \
# App                             object                     72605           0
# Category                        object                     72605           0
# Rating                         float64                     72605           0
# Reviews                          int64                     72605           0
# Size                            object                     72605           0
# Installs                         int64                     72605           0
# Type                            object                     72605           0
# Price                           object                     72605           0
# Content Rating                  object                     72605           0
# Genres                          object                     72605           0
# Last Updated            datetime64[ns]                     72605           0
# Current Ver                     object                     72605           0
# Android Ver                     object                     72605           0
# Size_in_MB                     float64                     45046       27559
# price_in_dollar                float64                     72605           0
# min_ver                        float64                     72605           0
# index                            int64                     72605           0
# Translated_Review               object                     72605           0
# Sentiment                       object                     72605           0
# Sentiment_Polarity             float64                     72605           0
# Sentiment_Subjectivity         float64                     72605           0
#
#                         % NaN values  unique_count
# App                         0.000000           816
# Category                    0.000000            33
# Rating                      0.000000            22
# Reviews                     0.000000          1068
# Size                        0.000000           168
# Installs                    0.000000            12
# Type                        0.000000             2
# Price                       0.000000             9
# Content Rating              0.000000             5
# Genres                      0.000000            68
# Last Updated                0.000000           251
# Current Ver                 0.000000           506
# Android Ver                 0.000000            22
# Size_in_MB                  0.379574           165
# price_in_dollar             0.000000             9
# min_ver                     0.000000            18
# index                       0.000000         35929
# Translated_Review           0.000000         26682
# Sentiment                   0.000000             3
# Sentiment_Polarity          0.000000          5295
# Sentiment_Subjectivity      0.000000          4382

# %%
# Checking for corelation between different variables
merged_df.corr()
# Out:
#                           Rating   Reviews  Installs  Size_in_MB  \
# Rating                  1.000000  0.129725 -0.002664    0.251717
# Reviews                 0.129725  1.000000  0.520766    0.539027
# Installs               -0.002664  0.520766  1.000000    0.266141
# Size_in_MB              0.251717  0.539027  0.266141    1.000000
# price_in_dollar        -0.013257 -0.030794 -0.033153   -0.038051
# min_ver                -0.106148 -0.056532 -0.207025    0.062437
# index                  -0.082323 -0.060632  0.179559   -0.153698
# Sentiment_Polarity      0.051783 -0.107390 -0.060528   -0.177298
# Sentiment_Subjectivity  0.056999 -0.018063 -0.010398    0.007969
#
#                         price_in_dollar   min_ver     index  \
# Rating                        -0.013257 -0.106148 -0.082323
# Reviews                       -0.030794 -0.056532 -0.060632
# Installs                      -0.033153 -0.207025  0.179559
# Size_in_MB                    -0.038051  0.062437 -0.153698
# price_in_dollar                1.000000  0.044842  0.029419
# min_ver                        0.044842  1.000000 -0.051793
# index                          0.029419 -0.051793  1.000000
# Sentiment_Polarity             0.028077 -0.041839  0.008479
# Sentiment_Subjectivity         0.007643  0.021726  0.003393
#
#                         Sentiment_Polarity  Sentiment_Subjectivity
# Rating                            0.051783                0.056999
# Reviews                          -0.107390               -0.018063
# Installs                         -0.060528               -0.010398
# Size_in_MB                       -0.177298                0.007969
# price_in_dollar                   0.028077                0.007643
# min_ver                          -0.041839                0.021726
# index                             0.008479                0.003393
# Sentiment_Polarity                1.000000                0.227486
# Sentiment_Subjectivity            0.227486                1.000000

# %%
# Correlation heatmap
# Heat Map for the merged data frame
plt.rcParams['figure.figsize'] = (22, 10)
sns.heatmap(merged_df.corr(), annot= True, cmap='Greens')
plt.title(' Heatmap for merged Dataframe', size=20)
# Out:
# Text(0.5, 1.0, ' Heatmap for merged Dataframe')

# %% [markdown]
# # Q2-What is the ratio of number of Paid apps and Free apps?

# %%
# Value counts of Type column
data = df['Type'].value_counts() 
labels = ['Free', 'Paid']

# %%
# create pie chart
plt.figure(figsize=(10,10))
colors = ["#00EE76","#7B8895"]
explode=(0.01,0.1)
plt.pie(data, labels = labels, colors = colors, autopct='%.2f%%',explode=explode,textprops={'fontsize': 15})
plt.title('Distribution of Paid and Free apps',size=15,loc='center')
plt.legend()

# %% [markdown]
# **Observation:**
#
# From the above graph we can see that 92.20% of apps in google play store are free and 7.8% are paid.
#
# # Q3-Distribution of apps in terms of rating
#
# Distribution of rating coloumn

# %%
#first check the distribution of the rating coloumn
plt.style.use('ggplot')
sns.displot(data=df["Rating"],kde = True,height=5, aspect=2,color="darkblue")
plt.xlabel("Rating", fontsize = 16)
plt.ylabel("Count", fontsize = 16)
plt.title("Distribution Of Rating", fontsize = 20)
plt.axvline(x=df["Rating"].mean(),color='red')

# %% [markdown]
# # **Observations**
#
# * Most of the apps are rated between 4.0 to 4.6
#
# * The average rating is close to 4.2

# %% [markdown]
# ## Number of apps in terms of ratings

# %%
#function to create color map list
def colormap():
  '''this function will return a color_list that as per the values of the df_rating_dist['Ratings'] series used for the color coding of 
     the bar chart representing df_rating_dist['Ratings'] series '''
  color_list=[]
  for i,item in df_rating_dist['Ratings'].iteritems():
    if item>=4:
      color_list.append("blue")
    elif item<4 and item>=3:
      color_list.append("yellow")
    else:
      color_list.append("red")
  return color_list

# %%
# bar chart for Number of apps with different ratings
df_rating_dist=df["Rating"].value_counts().reset_index().sort_values(by=['Rating'],ascending=False)
df_rating_dist.rename(columns = {'index':'Ratings', 'Rating':'Number of Apps',
                              }, inplace = True)
plt.style.use('ggplot')
bar=df_rating_dist.plot.bar(figsize=(20,8),x='Ratings',y='Number of Apps',color=colormap());
plt.xlabel("Ratings", fontsize = 16)
plt.ylabel("Number of Apps", fontsize = 16)
plt.title("Distribution Of Apps in Terms of Rating", fontsize = 20)
plt.yticks(fontsize=14);
plt.xticks(fontsize=14);

# %% [markdown]
# # **Observations**
# * Most number of app is rated with the rating 4.2,followed the rateings 4.3, 4.4, 4.5 respectively
# * Blue bars representing the apps rated with 4.0 or above contains the highest numbers of apps, followed by the yellow bars representing the apps rated between [3.0 to 4.0], followed by the red bars representing the apps rated bellow 3.0

# %% [markdown]
# **percentge distribution of top rated apps vs average rated apps vs low rated apps**

# %%
#function to group the rating coloumn in 3 category
def app_dist(item):
  '''function to convert the rateing column into 3 category'''
  if item>=4:
      return "top-rated apps"
  elif item<4 and item>=3:
      return "average-rated apps"
  else:
      return "low-rated apps"

# %%
#number of apps in terms of rating category 
df_app_dist=df['Rating'].apply(lambda x:app_dist(x)).value_counts().reset_index()
df_app_dist.rename(columns = { 'index':'Rating category','Rating':'Percentage of Apps',
                              }, inplace = True)
df_app_dist = df_app_dist.set_index('Rating category')
df_app_dist
# Out:
#                     Percentage of Apps
# Rating category
# top-rated apps                    7739
# average-rated apps                1630
# low-rated apps                     279

# %%
#pie chart for parcentage distribution of ratteing of the apps
explode = (0, 0.2, 0)
labels = 'Top-Rated apps', 'Average-Rated Apps', 'Low-Rated Apps',
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts=ax.pie(data=df_app_dist,x='Percentage of Apps',labels=labels,autopct='%1.1f%%',shadow=True,explode=explode,colors=['navajowhite','aquamarine','lightblue'],wedgeprops = wp,textprops = dict(color ="magenta"))
plt.setp(autotexts, size = 15, weight ="bold")
plt.legend( loc=1)
ax.set_title("Apps Percentage In Terms Of Different Category Rating");

# %% [markdown]
# # **Observations**
# * 80.2% apps are top rated app(4.0 or above)
# * 16.9% apps are average rated app(3.0 to 3.9)
# * 2.9% apps are low rated app(1 to 2.9)

# %% [markdown]
# # *Q4- Total number of apps in each category.*

# %%
# Creating temperory dataset which contain unique categories and no of apps in that category.
cat_df = df.groupby('Category')['App'].count().sort_values(ascending = False).reset_index()

# %%
# Plotting Bar graph.
fig =px.bar(cat_df,x= 'Category',y= 'App',labels={'App':'Number of Apps'},text_auto=True)
fig.update_layout(title_text='Number of Apps in each Category', title_x=0.5,titlefont=dict(size =22, color='black', family='Arial, sans-serif'))

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="16adf40d-2cd3-4ade-8934-1d4a56777d4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("16adf40d-2cd3-4ade-8934-1d4a56777d4e")) {                    Plotly.newPlot(                        "16adf40d-2cd3-4ade-8934-1d4a56777d4e",                        [{"alignmentgroup":"True","hovertemplate":"Category=%{x}<br>Number of Apps=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","texttemplate":"%{y}","x":["FAMILY","GAME","TOOLS","BUSINESS","MEDICAL","PERSONALIZATION","PRODUCTIVITY","LIFESTYLE","FINANCE","SPORTS","COMMUNICATION","HEALTH_AND_FITNESS","PHOTOGRAPHY","NEWS_AND_MAGAZINES","SOCIAL","BOOKS_AND_REFERENCE","TRAVEL_AND_LOCAL","SHOPPING","DATING","VIDEO_PLAYERS","MAPS_AND_NAVIGATION","EDUCATION","FOOD_AND_DRINK","ENTERTAINMENT","AUTO_AND_VEHICLES","LIBRARIES_AND_DEMO","WEATHER","HOUSE_AND_HOME","EVENTS","ART_AND_DESIGN","PARENTING","COMICS","BEAUTY"],"xaxis":"x","y":[1828,959,825,420,395,374,374,369,345,325,315,288,281,254,239,221,219,202,171,163,131,119,112,102,85,83,79,74,64,63,60,56,53],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222222222 ...

# %% [markdown]
# # **Observation:**
#
# As we can see most number of apps in the Playstore are of **Family** category followed by **Game** and **Tools** category. **Beauty** and **Comics** category has least number of apps.

# %% [markdown]
# # **Q5- Most apps in terms of content rating**

# %%
# Most apps in terms of Content Rating

df.groupby(['Content Rating'])['App'].count().reset_index()
# Out:
#     Content Rating   App
# 0  Adults only 18+     3
# 1         Everyone  7893
# 2     Everyone 10+   321
# 3       Mature 17+   393
# 4             Teen  1036
# 5          Unrated     2

# %%
# Checking value counts of Content Rating column
ax = df['Content Rating'].value_counts()
ax
# Out:
# Everyone           7893
# Teen               1036
# Mature 17+          393
# Everyone 10+        321
# Adults only 18+       3
# Unrated               2
# Name: Content Rating, dtype: int64

# %%
# Plotting bar graph of most apps in terms of content rating
plt.figure(figsize=(12,9))
ax.plot(kind='bar')
plt.title('Most apps in terms of content rating')
plt.ylabel('Apps')
plt.xlabel('Content Rating')
# Out:
# Text(0.5, 0, 'Content Rating')

# %%
# Plotting Content Rating using Pie-Chart.

fig = px.pie(df['Content Rating'] , names='Content Rating' , color='Content Rating')
fig.update_layout(title_text='Content Rating percentage wise',title_x=0.5,titlefont=dict(size=30,color='black',family='Arial , Halvetica'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f438bc97-14bd-46e6-9f34-f34fa00d4c2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f438bc97-14bd-46e6-9f34-f34fa00d4c2d")) {                    Plotly.newPlot(                        "f438bc97-14bd-46e6-9f34-f34fa00d4c2d",                        [{"customdata":[["Everyone"],["Everyone"],["Everyone"],["Teen"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone 10+"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone 10+"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Everyone 10+"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Everyone"],["Everyone"],["Mature 17+"],["Everyone 10+"],["Everyone"],["Everyone"],["Mature 17+"],["Mature 17+"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Everyone"],["Everyone 10+"],["Everyone"],["Teen"],["Everyone"],["Everyone"],["Teen"],["Everyone"],["Teen"],["Everyone"],["Everyone"],["Teen"],["Teen"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Mature 17+"],["Everyone"],["Everyone"],["Everyone"],["Mature 17+"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone 10+"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Everyone"],["Teen"],["Adults only 18+"],["Teen"],["Everyone"],["Everyone"],["Mature 17+"],[ ...

# %% [markdown]
# # **Observation:**
# There are around 8000 apps whose content is available for everyone which comes up to 81.8% of the total apps.

# %% [markdown]
# # Q6 - Top 10 categories in terms of number of installs

# %%
# Top 10 categories in number of installs

top_categories = df.groupby('Category')['Installs'].count().sort_values(ascending=False).head(10)
top_categories
# Out:
# Category
# FAMILY             1828
# GAME                959
# TOOLS               825
# BUSINESS            420
# MEDICAL             395
# PERSONALIZATION     374
# PRODUCTIVITY        374
# LIFESTYLE           369
# FINANCE             345
# SPORTS              325
# Name: Installs, dtype: int64

# %%
# Bar graph for top 10 categories in terms of number of installs
top_categories.plot(kind='bar')
plt.title("Top_10_installed_categories")
plt.ylabel('Installs')
plt.xlabel('Category')
# Out:
# Text(0.5, 0, 'Category')

# %% [markdown]
# # **Observation:**
#
# In the playstore , the top 10 categories are **FAMILY,GAME,TOOLS,BUSINESS,MEDICAL,PERSONALIZATION,PRODUCTIVITY,LIFESTYLE,FINANCE,SPORTS.**

# %% [markdown]
# ## **Q7-Top 10 apps of Free Type.**

# %%
# Dataframe of free type apps.
free_df=df[df['Type']=='Free']

# %%
# Top 10 free app by installs.
free_df[['App','Installs']].sort_values(by='Installs',ascending=False).head(10)
# Out:
#                                            App    Installs
# 2928                   Google Play Movies & TV  1000000000
# 1354                            Subway Surfers  1000000000
# 303                                      Gmail  1000000000
# 301               Google Chrome: Fast & Secure  1000000000
# 299                         WhatsApp Messenger  1000000000
# 298   Messenger – Text and Video Chat for Free  1000000000
# 2189                             Google Photos  1000000000
# 2906                                   YouTube  1000000000
# 700                          Google Play Games  1000000000
# 2418                 Maps - Navigate & Explore  1000000000

# %% [markdown]
# # **Q8- Top 10 apps of Paid type.**
#
# Paid apps can be classified on the basis of **revenue** they generated and not by number of installs.

# %%
# Creating Revenue column.
df['Revenue']= df['Installs']*df['price_in_dollar']

# %%
# Top apps of Paid type.
top_paid_df= df[df['Type']=='Paid'].sort_values(by='Revenue',ascending=False)

# %%
 # Top 10 Paid apps.
top_10_paid_apps=top_paid_df[['App','Revenue']].head(10)

# %%
# PLotting Bar graph for top 10 paid apps.
fig = px.bar(top_10_paid_apps,x='App',y='Revenue',color= 'App',text_auto=True)
fig.update_layout(title_text='Top 10 apps in Paid Type by Revenue', title_x=0.5,titlefont=dict(size =22, color='black', family='Arial, sans-serif'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="cbc98aa1-c899-4a93-b194-1059a19acdca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbc98aa1-c899-4a93-b194-1059a19acdca")) {                    Plotly.newPlot(                        "cbc98aa1-c899-4a93-b194-1059a19acdca",                        [{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Minecraft","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Minecraft","offsetgroup":"Minecraft","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Minecraft"],"xaxis":"x","y":[69900000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"I am rich","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"I am rich","offsetgroup":"I am rich","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["I am rich"],"xaxis":"x","y":[39999000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"I Am Rich Premium","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"I Am Rich Premium","offsetgroup":"I Am Rich Premium","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["I Am Rich Premium"],"xaxis":"x","y":[19999500.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Hitman Sniper","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Hitman Sniper","offsetgroup":"Hitman Sniper","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Hitman Sniper"],"xaxis":"x","y":[9900000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Grand Theft Auto: San Andreas","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Grand Theft Auto: San Andreas","offsetgroup":"Grand Theft Auto: San Andreas","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Grand Theft Auto: San Andreas"],"xaxis":"x","y":[6990000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Facetune - For Free","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Facetune - For Free","offsetgroup":"Facetune - For Free","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Facetune - For Free"],"xaxis":"x","y":[5990000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"Sleep as Android Unlock","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"Sleep as Android Unlock","offsetgroup":"Sleep as Android Unlock","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["Sleep as Android Unlock"],"xaxis":"x","y":[5990000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"DraStic DS Emulator","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"DraStic DS Emulator","offsetgroup":"DraStic DS Emulator","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["DraStic DS Emulator"],"xaxis":"x","y":[4990000.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"App=%{x}<br>Revenue=%{y}<extra></extra>","legendgroup":"I'm Rich - Trump Edition","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"I'm Rich - Trump Edition","offsetgroup":"I'm Rich - Trump Edition","orientation":"v","showlegend":true,"textposition":"auto","texttemplate ...

# %% [markdown]
# # **Observation:**
# App which has generated most revenue through download is **Minecraft** making **$69.9Millions**.

# %% [markdown]
# # Q9-Number of apps based on size

# %%
# Number of apps based on size

Number_of_apps = df.groupby(['Size_in_MB'])['App'].count().reset_index()
Number_of_apps
# Out:
#      Size_in_MB  App
# 0           0.0   27
# 1           0.1   34
# 2           0.2   47
# 3           0.3   32
# 4           0.4   29
# ..          ...  ...
# 186        96.0   23
# 187        97.0   11
# 188        98.0   13
# 189        99.0   30
# 190       100.0   14
#
# [191 rows x 2 columns]

# %%
def func(x):
  ''' Function to get the size of the app'''
  if (x <= 30):
    return "Small Size"
  elif(x >= 30) & (x <= 60):
    return "Medium Size"
  else:
    return "Large Size"

df['App_Size'] = df['Size_in_MB'].apply(func)
df.dropna(subset=['Size'])
# Out:
#                                                     App             Category  \
# 0        Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                   Coloring book moana       ART_AND_DESIGN
# 2     U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                 Sketch - Draw & Paint       ART_AND_DESIGN
# 4                 Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                 ...                  ...
# 9643                                   Sya9a Maroc - FR               FAMILY
# 9644                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 9645                             Parkinson Exercices FR              MEDICAL
# 9646                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 9647      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#       Rating  Reviews                Size  Installs  Type Price  \
# 0        4.1      159                 19M     10000  Free     0
# 1        3.9      967                 14M    500000  Free     0
# 2        4.7    87510                8.7M   5000000  Free     0
# 3        4.5   215644                 25M  50000000  Free     0
# 4        4.3      967                2.8M    100000  Free     0
# ...      ...      ...                 ...       ...   ...   ...
# 9643     4.5       38                 53M      5000  Free     0
# 9644     5.0        4                3.6M       100  Free     0
# 9645     4.2        3                9.5M      1000  Free     0
# 9646     4.5      114  Varies with device      1000  Free     0
# 9647     4.5   398307                 19M  10000000  Free     0
#
#      Content Rating                     Genres Last Updated  \
# 0          Everyone               Art & Design   2018-01-07
# 1          Everyone  Art & Design;Pretend Play   2018-01-15
# 2          Everyone               Art & Design   2018-08-01
# 3              Teen               Art & Design   2018-06-08
# 4          Everyone    Art & Design;Creativity   2018-06-20
# ...             ...                        ...          ...
# 9643       Everyone                  Education   2017-07-25
# 9644       Everyone                  Education   2018-07-06
# 9645       Everyone                    Medical   2017-01-20
# 9646     Mature 17+          Books & Reference   2015-01-19
# 9647       Everyone                  Lifestyle   2018-07-25
#
#              Current Ver         Android Ver  Size_in_MB  price_in_dollar  \
# 0                  1.0.0        4.0.3 and up        19.0              0.0
# 1                  2.0.0        4.0.3 and up        14.0              0.0
# 2                  1.2.4        4.0.3 and up         8.7              0.0
# 3     Varies with device          4.2 and up        25.0              0.0
# 4                    1.1          4.4 and up         2.8              0.0
# ...                  ...                 ...         ...              ...
# 9643                1.48          4.1 and up        53.0              0.0
# 9644                 1.0          4.1 and up         3.6              0.0
# 9645                 1.0          2.2 and up         9.5              0.0
# 9646  Varies with device  Varies with device         NaN              0.0
# 9647  Varies with device  Varies with device        19.0              0.0
#
#       min_ver  Revenue     App_Size
# 0         4.0      0.0   Small Size
# 1         4.0      0.0   Small Size
# 2         4.0      0.0   Small Size
# 3         4.2      0.0   Small Size
# 4         4.4      0.0   Small Size
# ...       ...      ...          ...
# 9643      4.1      0.0  Medium Size
# 9644      4.1      0.0   Small Size
# 9645      2.2      0.0   Small Size
# 9646      1.0      0.0   Large Size
# 9647      1.0      0.0   Small Size
#
# [9648 rows x 18 columns]

# %%
# Number of apps based on size
bx = df.groupby(['App_Size'])['Size_in_MB'].count()
bx
# Out:
# App_Size
# Large Size      600
# Medium Size    1301
# Small Size     6521
# Name: Size_in_MB, dtype: int64
